# %%
# %matplotlib inline
import plotnine as p9

# %%
import pandas as pd

# %%
surveys = pd.read_csv("https://ndownloader.figshare.com/files/10717177")
surveys.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35549 entries, 0 to 35548
# Data columns (total 9 columns):
# record_id          35549 non-null int64
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.4+ MB

# %%
surveys_complete = surveys.dropna()
surveys_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30676 entries, 62 to 35547
# Data columns (total 9 columns):
# record_id          30676 non-null int64
# month              30676 non-null int64
# day                30676 non-null int64
# year               30676 non-null int64
# plot_id            30676 non-null int64
# species_id         30676 non-null object
# sex                30676 non-null object
# hindfoot_length    30676 non-null float64
# weight             30676 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.3+ MB

# %%
surveys_complete.head()
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62         63      8   19  1977        3         DM   M             35.0
# 63         64      8   19  1977        7         DM   M             37.0
# 64         65      8   19  1977        4         DM   F             34.0
# 65         66      8   19  1977        4         DM   F             35.0
# 66         67      8   19  1977        7         DM   M             35.0
#
#     weight
# 62    40.0
# 63    48.0
# 64    29.0
# 65    46.0
# 66    36.0

# %%
(p9.ggplot(data=surveys_complete))
# Out:
# <ggplot: (7546288893)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length')))
# Out:
# <ggplot: (276972047)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point()
)
# Out:
# <ggplot: (-9223372029306977869)>

# %%
surveys_plot = (p9.ggplot(data=surveys_complete,
                         mapping=p9.aes(x='weight', y='hindfoot_length')))
surveys_plot
# Out:
# <ggplot: (7547797789)>

# %%
surveys_plot + p9.geom_point()
# Out:
# <ggplot: (-9223372029305674962)>

# %% [markdown]
# Working on the surveys_complete data set, use the plot-id column to create a bar-plot that counts the number of records for each plot. (Check the documentation of the bar geometry to handle the counts)

# %%
(p9.ggplot(data=surveys_complete, 
          mapping=p9.aes (x='plot_id'))
 +p9.geom_bar()
          )
# Out:
# <ggplot: (-9223372029306237664)>

# %%
surveys_plot + p9.geom_point(alpha=0.1)
# Out:
# <ggplot: (7547876956)>

# %%
surveys_plot + p9.geom_point(alpha=0.1, color='blue')
# Out:
# <ggplot: (7550253113)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
  + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (-9223372029304527167)>

# %% [markdown]
# **Try that same graph, but map the color to plot_id**

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='plot_id'))
  + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (7548736958)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
  + p9.geom_point(alpha=0.1)
  + p9.xlab("Weight (g)")
  + p9.ylab("Hindfoot Length (mm)")
)
# Out:
# <ggplot: (7550253141)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
  + p9.geom_point(alpha=0.1)
  + p9.xlab("Weight (g)")
  + p9.ylab("Hindfoot Length (mm)")
  + p9.scale_x_log10()
)
# Out:
# <ggplot: (7548939489)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
  + p9.geom_point(alpha=0.1)
  + p9.xlab("Weight (g)")
  + p9.ylab("Hindfoot Length (mm)")
  + p9.scale_x_log10()
  + p9.theme_bw()
  + p9.theme(text=p9.element_text(size=16))
)
# Out:
# <ggplot: (7547801783)>

# %% [markdown]
# Adapt the bar plot of the previous exercise by mapping the sex variable to the color fill of the bar chart. Change the scale of the color fill by providing the colors blue and orange manually (see API reference to find the appropriate function).

# %%
(p9.ggplot(data=surveys_complete, 
          mapping=p9.aes (x='plot_id'))
 +p9.geom_bar()
          )
# Out:
# <ggplot: (-9223372029306033618)>

# %%
(p9.ggplot(data=surveys_complete, 
          mapping=p9.aes (x='plot_id', color='sex'))
 +p9.geom_bar()
          )
# Out:
# <ggplot: (-9223372029305170614)>

# %%
(p9.ggplot(data=surveys_complete, 
          mapping=p9.aes (x='plot_id', fill='sex'))
 +p9.geom_bar()
          )
# Out:
# <ggplot: (7555633521)>

# %%
(p9.ggplot(data=surveys_complete, 
          mapping=p9.aes (x='plot_id', fill='sex'))
 +p9.geom_bar()
 +p9.scale_fill_manual(['blue','orange'])
          )
# Out:
# <ggplot: (7550427975)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
 + p9.geom_boxplot()
)
# Out:
# <ggplot: (-9223372029304744213)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
 + p9.geom_boxplot()
 + p9.geom_jitter(alpha=0.1)
)
# Out:
# <ggplot: (-9223372029306665500)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
 + p9.geom_boxplot()
 + p9.geom_jitter(alpha=0.1)
).save('boxplot.png', width=10, height=10, dpi=300)
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 10 x 10 in image.
#   from_inches(height, units), units), PlotnineWarning)
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: boxplot.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)

# %%
surveys_complete['plot_id'].unique()
# Out:
# array([ 3,  7,  4,  8,  2,  1,  6, 19, 23, 18,  5, 12, 11, 13, 20, 22, 17,
#        14, 16,  9, 21, 15, 24, 10])

# %%
for plot_id in surveys_complete['plot_id'].unique():
    print(plot_id)
# Out:
# 3
# 7
# 4
# 8
# 2
# 1
# 6
# 19
# 23
# 18
# 5
# 12
# 11
# 13
# 20
# 22
# 17
# 14
# 16
# 9
# 21
# 15
# 24
# 10

# %%
for plot_id in surveys_complete['plot_id'].unique():
    print(plot_id)
    filtered_survey = surveys_complete[surveys_complete['plot_id'] == plot_id]
    print(len(filtered_survey))
# Out:
# 3
# 1651
# 7
# 605
# 4
# 1778
# 8
# 1714
# 2
# 1960
# 1
# 1817
# 6
# 1384
# 19
# 1042
# 23
# 350
# 18
# 1262
# 5
# 1034
# 12
# 2110
# 11
# 1722
# 13
# 1280
# 20
# 1136
# 22
# 1229
# 17
# 1811
# 14
# 1648
# 16
# 452
# 9
# 1713
# 21
# 999
# 15
# 825
# 24
# 890
# 10
# 264
